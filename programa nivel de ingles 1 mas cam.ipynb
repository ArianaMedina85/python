# %% [markdown]
# <a href="https://colab.research.google.com/github/ArianaMedina85/python/blob/main/programa%20nivel%20de%20ingles%201%20mas%20cam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PROGRAMA PARA SABER EL NIVEL DE INGLES: A1, A2, B1, B2, C1 Y DETERMINAR SI ES ADMITIDO O RECHAZADO CON CALIFICACION MAYOR A 8.0  - ARIANA IA - ITSLP 08/10/25

# %%
#Leer datos
prom = float(input("ingrese promedio: "))


if prom < 8.0:
    print("rechazado por bajo promedio")
else:
  n1 = int(input("ingrese nivel de ingles (A1=1, A2=2, B1=3, B2=4, C1=5) : "))
  if n1 > 2 :
        print("admitido")


  else:
        print("rechazado por bajo nivel de ingles")
# Out:
# ingrese promedio: 8
# ingrese nivel de ingles (A1=1, A2=2, B1=3, B2=4, C1=5) : 3
# admitido

# %%
n1 = int(input("ingrese nivel de ingles (A1=1, A2=2, B1=3, B2=4, C1=5) : "))
prom = float(input("ingrese promedio: "))

if n1 > 2 and prom >= 8.0:
  print("usted es admitido")
elif prom < 8.0:
  print("RECHAZADO:su promedio no es suficiente")
elif n1 <= 2:
  print("RECHAZADO: su nivel de ingles no es suficiente")
