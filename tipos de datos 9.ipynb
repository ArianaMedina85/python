# %% [markdown]
# <a href="https://colab.research.google.com/github/ArianaMedina85/python/blob/main/tipos%20de%20datos%209.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tipos de datos que usamos en la unidad. FUNDAMENTOS DE PROGRAMACION

# %%
nom = ('dominic')
ap = (' loredo')
nombre = nom + ap
print(nombre)
# Out:
# dominic loredo

# %%
A = 3.5
B = 4
sum= A+B
print (sum)
# Out:
# 7.5

# %%
base = float(input('ingrese la base '))
altura = float(input('ingrese la altura '))
A = (base * altura) / 2
per = 3 * base
print(f"area es, {A:.2f}")
print(f"perimetro es {per:.2f}")
# Out:
# ingrese la base 65.56
# ingrese la altura 23.89
# area es, 783.11
# perimetro es 196.68

# %%
x = float(input("ingrese valor de x: "))

if x <= 0.0:
  print("x es menor o igual que 0.0")
elif 0 < x <= 1:
  print("x es mayor que 0 pero menor o igual que 1")
else:
  print("x  es mayor que 1")
