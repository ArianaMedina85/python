# %% [markdown]
# <a href="https://colab.research.google.com/github/ArianaMedina85/python/blob/main/Programa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ITSLP- **FUNDAMENNTOS DE PROGRAMACION**- Programa que encuentra entre dos numeros diferentes al mayor- ARIANA 03/10/25

# %%
num1 = 0
num2 = 0
num1 = input("ingrese el valor de num1:")
num2 = input("ingrese el valor de num2:")
if num1 > num2:
  print("el nuero mayor es:", num1)
else:
  print("el numero mayor es:", num2)
# Out:
# ingrese el valor de num1:6
# ingrese el valor de num2:4
# el nuero mayor es: 6

# %%
num1 = input("ingrese el valor de num1:")
num2 = input("ingrese el valor de num2:")
if num1 > num2:
  m = num1
else:
    m = num2
print("el numero mayor es:", m)
# Out:
# ingrese el valor de num1:5
# ingrese el valor de num2:8
# el numero mayor es: 8
