# %% [markdown]
# <a href="https://colab.research.google.com/github/ArianaMedina85/python/blob/main/programa2.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ITSLP- **FUNDAMENNTOS DE PROGRAMACION**- Programa que encuentra entre dos numeros diferentes al mayor- ARIANA 03/10/25

# %%
#Leer los datos
num1 = 0
num2 = 0
#
num1 = input("ingrese el valor de num1:")
num2 = input("ingrese el valor de num2:")
#
if num1 > num2:
  print("el nuero mayor es:", num1)
else:
  print("el numero mayor es:", num2)

# %% [markdown]
# # New Section

# %%
#leer datos
num1 = input("ingrese el valor de num1:")
num2 = input("ingrese el valor de num2:")

#condicionamos el resultado
if num1 > num2:
  m = num1
else:
  m = num2
#imprimir el resultado
print("el numero mayor es:", m)
# Out:
# ingrese el valor de num1:8
# ingrese el valor de num2:2
# el numero mayor es: 8

# %% [markdown]
# **PROGRAMA PARA SACAR EL AREA DE UN TRIANGULO**

# %%
# Leer los valores
b = input("ingrese el valor de b:")
h = input("ingrese el valor de h:")
# hacer operacion
a = (int(b)*int(h))/2
# imprimir el resultado
print("el area del triangulo es:", a)
# Out:
# ingrese el valor de b:6
# ingrese el valor de h:4
# el area del triangulo es: 12.0
