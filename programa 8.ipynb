# %% [markdown]
# <a href="https://colab.research.google.com/github/ArianaMedina85/python/blob/main/programa%208.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
float n1; n2
n1=input(introduzca el primer numero)
n2=input(introduzca el segundo numero)
operacion=str(input(introduzca la operacion a realizar (*,/;\,+,-)))
match opetacion:
  case "+":
    print(n1*n2)
